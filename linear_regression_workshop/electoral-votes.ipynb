# %%
import pandas as pd
import statsmodels.api as sm
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
df_historical = pd.read_csv('Camp_Election.Oracle\\Historical Election Results\\MIT_Lab_Historical_Election_Results\\1976-2020-president.csv')
df_historical = df_historical[['year', 'state', 'candidate', 'candidatevotes', 'totalvotes','party_simplified']]
clean_tfc = pd.read_csv('clean_TFC_data.csv')
clean_tfc.head(5)
# Out:
#    year       state  pct_2p_vote  term2  real_gdp_pct_growth  net_approval
# 0  1976     ALABAMA    43.333276      0                  5.4             5
# 1  1976      ALASKA    61.891829      0                  5.4             5
# 2  1976     ARIZONA    58.613303      0                  5.4             5
# 3  1976    ARKANSAS    34.951149      0                  5.4             5
# 4  1976  CALIFORNIA    50.917827      0                  5.4             5

# %%
df_historical.head(5)
# Out:
#    year    state                candidate  candidatevotes  totalvotes  \
# 0  1976  ALABAMA            CARTER, JIMMY          659170     1182850
# 1  1976  ALABAMA             FORD, GERALD          504070     1182850
# 2  1976  ALABAMA           MADDOX, LESTER            9198     1182850
# 3  1976  ALABAMA  BUBAR, BENJAMIN ""BEN""            6669     1182850
# 4  1976  ALABAMA                HALL, GUS            1954     1182850
#
#   party_simplified
# 0         DEMOCRAT
# 1       REPUBLICAN
# 2            OTHER
# 3            OTHER
# 4            OTHER

# %%
df = pd.merge(df_historical, clean_tfc, on = ['year', 'state'])

# %%
df.head(5)
# Out:
#    year    state                candidate  candidatevotes  totalvotes  \
# 0  1976  ALABAMA            CARTER, JIMMY          659170     1182850
# 1  1976  ALABAMA             FORD, GERALD          504070     1182850
# 2  1976  ALABAMA           MADDOX, LESTER            9198     1182850
# 3  1976  ALABAMA  BUBAR, BENJAMIN ""BEN""            6669     1182850
# 4  1976  ALABAMA                HALL, GUS            1954     1182850
#
#   party_simplified  pct_2p_vote  term2  real_gdp_pct_growth  net_approval
# 0         DEMOCRAT    43.333276      0                  5.4             5
# 1       REPUBLICAN    43.333276      0                  5.4             5
# 2            OTHER    43.333276      0                  5.4             5
# 3            OTHER    43.333276      0                  5.4             5
# 4            OTHER    43.333276      0                  5.4             5

# %%
enc = OneHotEncoder()
scaler = StandardScaler()
